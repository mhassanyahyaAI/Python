# %%
import pandas as pd
import numpy as np
from numpy import nan as na

# %%
df = pd.read_csv("data for panda exercise.csv")
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.shape
# Out:
# (48, 14)

# %%
df.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0     6.0
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0     6.0
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0     6.0
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0     4.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
df.tail(10)
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 38  022-14-110229  BS(CS)   Sadaquat Rafique    9     6.0     6.0
# 39  022-14-110107  BS(CS)        Sania Iqbal   28     4.0     4.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 41  022-14-110225  BS(CS)      Shariqa Ahmad   20     7.0     6.0
# 42  022-14-110587  BS(CS)      Sumbul Rehman   28     5.0     6.0
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 38                6           5.0           7.0                    7
# 39                4           9.0          11.0                   11
# ...

# %%
sum(df.Grade == 'A')
# Out:
# 8

# %%
df[df['Best of Assignments']>5]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# ...

# %%
df[df.Mid >25].count()
# Out:
# Student Code            20
# Degree                  20
# Student Name            20
# Mid                     20
# Quiz 1                  20
# Quiz 2                  18
# Best of Quizzes         20
# Assignment 1            20
# Assignment 2            14
# Best of Assignments     20
# Total Sessional (50)    20
# Final (50)              20
# Total (100)             20
# Grade                   20
# dtype: int64

# %%
df [4:5]
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 4                    43        34.0           77     B

# %%
df
# Out:
#      Student Code  Degree            Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)  Muhammad Ghazali Farid   28     8.0     3.0
# 1   022-14-110233  BS(CS)  Muhammad Ghazali Farid   17     NaN     5.0
# 2   022-14-110585  BS(CS)  Muhammad Ghazali Farid   18     5.0     2.0
# 3    022-14-19718  BS(CS)  Muhammad Ghazali Farid   14     7.0     2.0
# 4   022-14-110648  BS(CS)  Muhammad Ghazali Farid   27     7.0     6.0
# 5   022-14-110232  BS(CS)  Muhammad Ghazali Farid   25     9.0     6.0
# 6   022-14-110588  BS(CS)  Muhammad Ghazali Farid   28     5.0     6.0
# 7   022-14-110388  BS(CS)  Muhammad Ghazali Farid   26     9.0     6.0
# 8   022-14-110601  BS(CS)  Muhammad Ghazali Farid   19     9.0     4.0
# 9   022-14-110599  BS(CS)  Muhammad Ghazali Farid   28     8.0     6.0
# 10  022-14-110214  BS(CS)  Muhammad Ghazali Farid   30     8.0     7.0
# 11  022-14-110591  BS(CS)  Muhammad Ghazali Farid   28     8.0     5.0
# ...

# %%
df[df['Student Name']=='Muhammad Ghazali Faridi']
# Out:
#      Student Code  Degree             Student Name  Mid  Quiz 1  Quiz 2  \
# 26  022-14-110370  BS(CS)  Muhammad Ghazali Faridi   27     6.0     NaN
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 26                6           6.0           8.0                    8
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 26                    41        24.0           65     C

# %%
df.iloc[5:18,9:10]
# Out:
#     Best of Assignments
# 5                    10
# 6                    10
# 7                    10
# 8                     9
# 9                     8
# 10                    8
# 11                    5
# 12                   10
# 13                   10
# 14                    8
# 15                    0
# 16                    9
# 17                   11

# %%
df.iloc[1::2]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# ...

# %%
a = df.dropna()
a
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# ...

# %%
df[(df['Grade'] == 'A') & df['Student Name'].str.startswith('A')]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 7                    45        40.0           85     A
# 9                    44        40.0           84     A

# %%
df[['Student Name', 'Assignment 1','Grade']][(df.Grade == 'A')]
# Out:
#            Student Name  Assignment 1 Grade
# 7      Aneebullah Niazi           8.0     A
# 9               Arsalan           8.0     A
# 10  Fatima Haider Warsi           8.0     A
# 19      Mohammad Hunain           8.0     A
# 25       Muhammad Faraz           8.0     A
# 34     Nazeer Bin Zafar           8.0     A
# 40          Sharif Taqi           8.0     A
# 45    Syeda Sabika Raza           9.0     A

# %%
df[df['Student Name'].str.contains('Ali')]
# Out:
#      Student Code  Degree        Student Name  Mid  Quiz 1  Quiz 2  \
# 3    022-14-19718  BS(CS)      Ahmed Ali Raza   14     7.0     2.0
# 4   022-14-110648  BS(CS)     Ahsan Ali Vohra   27     7.0     6.0
# 6   022-14-110588  BS(CS)       Anas Ali Khan   28     5.0     6.0
# 23   022-14-19983  BS(CS)  Muhammad Ali Iqbal   26     5.0     NaN
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 3                 7           NaN           2.0                    2
# 4                 7           7.0           9.0                    9
# 6                 6           8.0          10.0                   10
# 23                5           8.0          10.0                   10
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 3                     23        23.0           46     F
# 4                     43        34.0           77     B
# 6                     44        30.0           74     B
# 23                    41        21.0           62     C

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.fillna({'Quiz 1':5,'Quiz 2' :5, 'Assignment 1': -5, 'Assignment 2': -5,
           'Mid':df['Final (50)']*3/4,
           'Final (50)':df['Mid']*3/4}, inplace = True)

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     5.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
 df['Status'] = df['Grade'].apply(lambda x : 'Fail' if x == 'F' else 'Pass')

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     5.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df['Total (100)'].rename('Grand Total',inplace = True)
# Out:
# 0     70
# 1     50
# 2     63
# 3     46
# 4     77
# 5     71
# 6     74
# 7     85
# 8     61
# 9     84
# 10    91
# 11    76
# 12    73
# 13    67
# 14    65
# 15    18
# 16    72
# 17    70
# 18    60
# 19    91
# 20    71
# 21    60
# 22    57
# 23    62
# 24    77
# 25    86
# 26    65
# 27    71
# 28    57
# 29    39
# 30    72
# 31    73
# 32    29
# 33    51
# 34    86
# 35    66
# 36    70
# 37    75
# 38    39
# 39    68
# 40    81
# 41    57
# 42    67
# 43    79
# 44    63
# 45    80
# 46    65
# 47    46
# Name: Grand Total, dtype: int64

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     5.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.rename(columns = {'Total(100)':'Grand Total'}, inplace = True)

# %%
df['Sum of Quizzes'] = df['Quiz 1'] + df['Quiz 2']

# %%
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     5.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...
